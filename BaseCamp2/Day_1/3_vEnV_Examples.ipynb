# %% [markdown]
# ### Virtual Environment
#
# 2 different virtual environment is created and used for the cells below
# Try activating different environment and execute the code cells

# %%
# Import the Groq library
from groq import Groq
from os import environ

groq_api_key = environ.get("GROQ_API_KEY")

# Create a groq client
if groq_api_key is None:
    print("Could not fetch the API key from the environment variable 'GROQ_API_KEY'.")
else:
    G_client = Groq(api_key=groq_api_key)
# Out:
# Could not fetch the API key from the environment variable 'GROQ_API_KEY'.

# %%
# Import pandas library and create a data frame
import pandas as pd

# Create a data frame
DF = pd.DataFrame ({'C1' : [1,2,3], 'C2' : [2,3,4]})
print(DF)
# Out:
#    C1  C2
# 0   1   2
# 1   2   3
# 2   3   4
